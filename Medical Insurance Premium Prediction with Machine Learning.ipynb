# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file 
insurance_df = pd.read_csv('insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # TASK #3: PERFORM EXPLORATORY DATA ANALYSIS - PART 1

# %%
insurance_df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# check if there are any Null values
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
# check if there are any Null values
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check the dataframe info
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Grouping by region to see any relationship between region and charges
# Seems like south east region has the highest charges and body mass index
df_region = insurance_df.groupby(by = 'region').mean()
df_region
# Out:
# C:\Users\talha\AppData\Local\Temp\ipykernel_25248\260334472.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_region = insurance_df.groupby(by = 'region').mean()
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# # TASK #4: PERFORM FEATURE ENGINEERING

# %%
# Check unique values in the 'sex' column
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical
insurance_df['sex']=insurance_df['sex'].apply(lambda x:0 if x == 'female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
# Check the unique values in the 'smoker' column
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convert categorical variable to numerical 
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400          0
# 1   18    1  33.770         1       0  southeast   1725.55230          0
# 2   28    1  33.000         3       0  southeast   4449.46200          0
# 3   33    1  22.705         0       0  northwest  21984.47061          1
# 4   32    1  28.880         0       0  northwest   3866.85520          1
#
#    southeast  southwest
# 0          0          1
# 1          1          0
# 2          1          0
# 3          0          0
# 4          0          0

# %%
# Let's drop the original 'region' column 
insurance_df.drop(['region'], axis = 1, inplace = True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400          0          0
# 1   18    1  33.770         1       0   1725.55230          0          1
# 2   28    1  33.000         3       0   4449.46200          0          1
# 3   33    1  22.705         0       0  21984.47061          1          0
# 4   32    1  28.880         0       0   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # TASK #5: PERFORM DATA VISUALIZATION

# %%
insurance_df[['age','sex','bmi','children','smoker','charges']].hist(bins = 30, figsize = (12,12))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>],
#        [<Axes: title={'center': 'bmi'}>,
#         <Axes: title={'center': 'children'}>],
#        [<Axes: title={'center': 'smoker'}>,
#         <Axes: title={'center': 'charges'}>]], dtype=object)

# %%
# plot pairplot
sns.pairplot(insurance_df)

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %%
insurance_df.corr()
# Out:
#                 age       sex       bmi  children    smoker   charges  \
# age        1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# sex       -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi        0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children   0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker    -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges    0.299008  0.057292  0.198341  0.067998  0.787251  1.000000
# northwest -0.000407 -0.011156 -0.135996  0.024806 -0.036945 -0.039905
# southeast -0.011642  0.017117  0.270025 -0.023066  0.068498  0.073982
# southwest  0.010016 -0.004184 -0.006205  0.021914 -0.036945 -0.043210
#
#            northwest  southeast  southwest
# age        -0.000407  -0.011642   0.010016
# sex        -0.011156   0.017117  -0.004184
# bmi        -0.135996   0.270025  -0.006205
# children    0.024806  -0.023066   0.021914
# smoker     -0.036945   0.068498  -0.036945
# charges    -0.039905   0.073982  -0.043210
# northwest   1.000000  -0.346265  -0.320829
# southeast  -0.346265   1.000000  -0.346265
# southwest  -0.320829  -0.346265   1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(insurance_df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # TASK #6: CREATE TRAINING AND TESTING DATASET

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
x = insurance_df.drop(columns = ['charges'])
y = insurance_df['charges']

# %%
x
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1          0          0          1
# 1      18    1  33.770         1       0          0          1          0
# 2      28    1  33.000         3       0          0          1          0
# 3      33    1  22.705         0       0          1          0          0
# 4      32    1  28.880         0       0          1          0          0
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0          1          0          0
# 1334   18    0  31.920         0       0          0          0          0
# 1335   18    0  36.850         0       0          0          1          0
# 1336   21    0  25.800         0       0          0          0          1
# 1337   61    0  29.070         0       1          1          0          0
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
x = np.array(x).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
# Only take the numerical variables and scale them
x
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
y.shape
# Out:
# (1338, 1)

# %%
#scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler_x = StandardScaler()
x = scaler_x.fit_transform(x)

scaler_y = StandardScaler()
y = scaler_y.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

print(x_train.shape)
print(x_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# # TASK #7: TRAIN AND EVALUATE A LINEAR REGRESSION MODEL IN SCIKIT-LEARN

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

reg_mod_sk = LinearRegression()
reg_mod_sk.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg_mod_sk_accuracy = reg_mod_sk.score(x_test, y_test)
reg_mod_sk_accuracy
# Out:
# 0.7470298206276421

# %%
y_predict = reg_mod_sk.predict(x_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = x_test.shape[1]
n = len(x_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt


RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 6311.243
# MSE = 39831784.0
# MAE = 4403.4785
# R2 = 0.7470298268273972
# Adjusted R2 = 0.7392160763046913

# %% [markdown]
# # TASK #8: TRAIN AND EVALUATE AN ARTIFICIAL NEURAL NETWORK-BASED REGRESSION MODEL

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Activation, Dropout, BatchNormalization
from keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                450
#
#  activation (Activation)     (None, 50)                0
#
#  dense_1 (Dense)             (None, 150)               7650
#
#  activation_1 (Activation)   (None, 150)               0
#
#  dense_2 (Dense)             (None, 150)               22650
#
#  activation_2 (Activation)   (None, 150)               0
#
#  dense_3 (Dense)             (None, 50)                7550
#
#  activation_3 (Activation)   (None, 50)                0
#
#  dense_4 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 38351 (149.81 KB)
# Trainable params: 38351 (149.81 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')
epochs_hist = ANN_model.fit(x_train, y_train, epochs = 100, batch_size = 20, validation_split = 0.2)
# Out:
# Epoch 1/100
# 43/43 [==============================] - 2s 9ms/step - loss: 0.4157 - val_loss: 0.1383
# Epoch 2/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1792 - val_loss: 0.1299
# Epoch 3/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1708 - val_loss: 0.1542
# Epoch 4/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1736 - val_loss: 0.1338
# Epoch 5/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1470 - val_loss: 0.1180
# Epoch 6/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1384 - val_loss: 0.1268
# Epoch 7/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1387 - val_loss: 0.1308
# Epoch 8/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1356 - val_loss: 0.1202
# Epoch 9/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1307 - val_loss: 0.1479
# Epoch 10/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1268 - val_loss: 0.1287
# Epoch 11/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1215 - val_loss: 0.1336
# Epoch 12/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1270 - val_loss: 0.1239
# Epoch 13/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1223 - val_loss: 0.1190
# Epoch 14/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1162 - val_loss: 0.1329
# Epoch 15/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1178 - val_loss: 0.1329
# Epoch 16/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1124 - val_loss: 0.1292
# Epoch 17/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1107 - val_loss: 0.1328
# Epoch 18/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1113 - val_loss: 0.1471
# Epoch 19/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1096 - val_loss: 0.1223
# Epoch 20/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1074 - val_loss: 0.1375
# Epoch 21/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1031 - val_loss: 0.1273
# Epoch 22/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1041 - val_loss: 0.1269
# Epoch 23/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1030 - val_loss: 0.1466
# Epoch 24/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1044 - val_loss: 0.1428
# Epoch 25/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1040 - val_loss: 0.1337
# Epoch 26/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0995 - val_loss: 0.1355
# Epoch 27/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1006 - val_loss: 0.1311
# Epoch 28/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1048 - val_loss: 0.1424
# Epoch 29/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0951 - val_loss: 0.1349
# Epoch 30/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0940 - val_loss: 0.1614
# Epoch 31/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0981 - val_loss: 0.1485
# Epoch 32/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0951 - val_loss: 0.1342
# Epoch 33/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0983 - val_loss: 0.1560
# Epoch 34/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1099 - val_loss: 0.1604
# Epoch 35/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0906 - val_loss: 0.1427
# Epoch 36/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0899 - val_loss: 0.1385
# Epoch 37/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0848 - val_loss: 0.1333
# Epoch 38/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0852 - val_loss: 0.1295
# Epoch 39/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0840 - val_loss: 0.1457
# Epoch 40/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0831 - val_loss: 0.1479
# Epoch 41/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0809 - val_loss: 0.1408
# Epoch 42/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0807 - val_loss: 0.1502
# Epoch 43/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0801 - val_loss: 0.1464
# Epoch 44/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0759 - val_loss: 0.1669
# Epoch 45/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0773 - val_loss: 0.1590
# Epoch 46/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0728 - val_loss: 0.1463
# Epoch 47/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0755 - val_loss: 0.1507
# Epoch 48/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0791 - val_loss: 0.1533
# Epoch 49/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.1427
# Epoch 50/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0712 - val_loss: 0.1478
# Epoch 51/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0713 - val_loss: 0.1400
# Epoch 52/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.1594
# Epoch 53/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0721 - val_loss: 0.1674
# Epoch 54/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0699 - val_loss: 0.1562
# Epoch 55/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0650 - val_loss: 0.1623
# Epoch 56/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0623 - val_loss: 0.1488
# Epoch 57/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0636 - val_loss: 0.1696
# Epoch 58/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0668 - val_loss: 0.1690
# Epoch 59/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0621 - val_loss: 0.1609
# Epoch 60/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0616 - val_loss: 0.1556
# Epoch 61/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0646 - val_loss: 0.1644
# Epoch 62/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0627 - val_loss: 0.1694
# Epoch 63/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0680 - val_loss: 0.1549
# Epoch 64/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0650 - val_loss: 0.1570
# Epoch 65/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0618 - val_loss: 0.1732
# Epoch 66/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0608 - val_loss: 0.1982
# Epoch 67/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0601 - val_loss: 0.1641
# Epoch 68/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0588 - val_loss: 0.1452
# Epoch 69/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0569 - val_loss: 0.1619
# Epoch 70/100
# 43/43 [==============================] - 0s 4ms/step - loss: 0.0525 - val_loss: 0.1657
# Epoch 71/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0576 - val_loss: 0.1705
# Epoch 72/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0555 - val_loss: 0.1423
# Epoch 73/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.1660
# Epoch 74/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0558 - val_loss: 0.1799
# Epoch 75/100
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0606 - val_loss: 0.1734
# Epoch 76/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0554 - val_loss: 0.1781
# Epoch 77/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0519 - val_loss: 0.1546
# Epoch 78/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0521 - val_loss: 0.1677
# Epoch 79/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0537 - val_loss: 0.1752
# Epoch 80/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0505 - val_loss: 0.1709
# Epoch 81/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0497 - val_loss: 0.1684
# Epoch 82/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0529 - val_loss: 0.1686
# Epoch 83/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0581 - val_loss: 0.1832
# Epoch 84/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0636 - val_loss: 0.1858
# Epoch 85/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0540 - val_loss: 0.1768
# Epoch 86/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0481 - val_loss: 0.1792
# Epoch 87/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0448 - val_loss: 0.2034
# Epoch 88/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0446 - val_loss: 0.1871
# Epoch 89/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0469 - val_loss: 0.1794
# Epoch 90/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0443 - val_loss: 0.1673
# Epoch 91/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0439 - val_loss: 0.1735
# Epoch 92/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0455 - val_loss: 0.1836
# Epoch 93/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.1854
# Epoch 94/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0429 - val_loss: 0.1913
# Epoch 95/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0462 - val_loss: 0.1784
# Epoch 96/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0472 - val_loss: 0.2130
# Epoch 97/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0460 - val_loss: 0.1851
# Epoch 98/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0434 - val_loss: 0.1911
# Epoch 99/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0426 - val_loss: 0.1783
# Epoch 100/100
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0425 - val_loss: 0.1803

# %%
result = ANN_model.evaluate(x_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.2425
# Accuracy : 0.7574874013662338

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = ANN_model.predict(x_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = x_test.shape[1]
n = len(x_test)
n

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 5961.415
# MSE = 35538464.0
# MAE = 3669.3904
# R2 = 0.7742965425302003
# Adjusted R2 = 0.7673250071643378
